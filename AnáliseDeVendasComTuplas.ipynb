# %%
vendas_produtos = [('iphone', 558147, 951642),
('galaxy', 712350, 244295), 
('ipad', 573823, 26964), 
('tv', 405252, 787604), 
('máquina de café', 718654, 867660), 
('kindle', 531580, 78830), 
('geladeira', 973139, 710331), 
('adega', 892292, 646016), 
('notebook dell', 422760, 694913), 
('notebook hp', 154753, 539704), 
('notebook asus', 887061, 324831), 
('microsoft surface', 438508, 667179), 
('webcam', 237467, 295633), 
('caixa de som', 489705, 725316), 
('microfone', 328311, 644622), 
('câmera canon', 591120, 994303)]

searchlist = [['s', 'sim', 'desejo', 'quero', 'si', 'sí' ],
    ['n', 'não', 'não quero', 'não desejo', 'nao', 'na', 'no'],
    ]
search = input('Deseja ver se as vendas de 2022 foram maiores do que as de 2021?')

if search in searchlist[0]:

    print('=' * 34, 'TABELA 2022', '=' * 33)
    print('|\033[93m{:^20}\033[0m|\033[93m{:^15}\033[0m|\033[93m{:^15}\033[0m|\033[93m{:^25}\033[0m|'.format('Produtos', 'Vendas 2021','Vendas 2022','Crescimento em %'))
    print('=' * 80)

    venda2021_total = 0
    venda2022_total = 0

    for lista in vendas_produtos:
        produto, venda2021, venda2022 = lista

        if venda2022 > venda2021:

            venda2021_total += venda2021
            venda2022_total += venda2022

            a = produto
            b = '{:_}'.format(venda2021).replace("_", ".")
            c = '{:_}'.format(venda2022).replace("_", ".")
            d = '{:.1%}'.format(venda2022 / venda2021 - 1)

            print(f'|\033[1m{a:<20}\033[0m|{b:^15}|{c:^15}|{d:^25}|')
            print('=' * 20, '+', '=' * 13, '+', '=' * 13, '+',  '=' * 23, '+')

    a1 = 'SUBTOTAL:'
    b1 = venda2021_total
    c1 = venda2022_total
    d1 = venda2022_total / venda2021_total - 1

    print(f'\033[92m\033[1m|{a1:<20}|{b1:^15_}|{c1:^15_}|{d1:^25.1%}|\033[0m'.replace("_", "."))


elif search in searchlist[1]:
    search2 = input('Deseja comparar a de 2021 à 2022?')

    if search2 in searchlist[0]:

        print('=' * 34, 'TABELA 2021', '=' * 33)
        print('|\033[93m{:^20}\033[0m|\033[93m{:^15}\033[0m|\033[93m{:^15}\033[0m|\033[93m{:^25}\033[0m|'.format('Produtos', 'Vendas 2021','Vendas 2022','Crescimento em %'))
        print('=' * 80)

        venda2021_total = 0
        venda2022_total = 0

        for lista in vendas_produtos:
            produto, venda2021, venda2022 = lista

            if venda2021 > venda2022:
                venda2021_total += venda2021
                venda2022_total += venda2022

                a = produto
                b = '{:_}'.format(venda2021).replace("_", ".")
                c = '{:_}'.format(venda2022).replace("_", ".")
                d = '{:.1%}'.format(venda2022 / venda2021 - 1)

                print(f'|\033[1m{a:<20}\033[0m|{b:^15}|{c:^15}|{d:^25}|')
                print('=' * 20, '+', '=' * 13, '+', '=' * 13, '+',  '=' * 23, '+')

        a1 = 'SUBTOTAL:'
        b1 = venda2021_total
        c1 = venda2022_total
        d1 = venda2022_total / venda2021_total - 1

        print(f'\033[92m\033[1m|{a1:<20}|{b1:^15_}|{c1:^15_}|{d1:^25.1%}|\033[0m'.replace("_", "."))


    elif search in searchlist[1]:
        search3 =  input('Deseja ver todos os itens?')

        if search3 in searchlist[0]:

            print('=' * 20, 'TABELA GERAL', '=' * 21)
            print('|\033[93m{:^20}\033[0m|\033[93m{:^15}\033[0m|\033[93m{:^15}\033[0m|'.format('Produtos', 'Vendas 2021','Vendas 2022'))
            print('=' * 54)

            venda2021_total = 0
            venda2022_total = 0

            for lista in vendas_produtos:
                produto, venda2021, venda2022 = lista

                if True:
                    venda2021_total += venda2021
                    venda2022_total += venda2022

                    a = produto
                    b = '{:_}'.format(venda2021).replace("_", ".")
                    c = '{:_}'.format(venda2022).replace("_", ".")

                    print(f'|\033[1m{a:<20}\033[0m|{b:^15}|{c:^15}|')
                    print('=' * 20, '+', '=' * 13, '+', '=' * 13, '+')

            a1 = 'SUBTOTAL:'
            b1 = venda2021_total
            c1 = venda2022_total
            
            print(f'\033[92m\033[1m|{a1:<20}|{b1:^15_}|{c1:^15_}|\033[0m'.replace("_", "."))
# Out:
# ================================== TABELA 2022 =================================
# |      Produtos      |  Vendas 2021  |  Vendas 2022  |    Crescimento em %     |
# ...
# |iphone              |    558.147    |    951.642    |          70.5%          |
# ==================== + ============= + ============= + ======================= +
# |tv                  |    405.252    |    787.604    |          94.3%          |
# ==================== + ============= + ============= + ======================= +
# |máquina de café     |    718.654    |    867.660    |          20.7%          |
# ==================== + ============= + ============= + ======================= +
# |notebook dell       |    422.760    |    694.913    |          64.4%          |
# ==================== + ============= + ============= + ======================= +
# |notebook hp         |    154.753    |    539.704    |         248.8%          |
# ==================== + ============= + ============= + ======================= +
# ...
